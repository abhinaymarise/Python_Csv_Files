# %% [markdown]
# # 2. Standardizing contact details in an Excel file for a marketing campaign using  customer data

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('us_customer_data 1.csv')

# %%
countries=pd.read_csv(r'Country-codes.csv',encoding='latin1')

# %%
countries
# Out:
#                                                Country Country_code  \
# 0                                                    A          NaN
# 1                                         Afghanistan            AF
# 2                                             Albania            AL
# 3                                             Algeria            DZ
# 4                                       American Samoa           AS
# ..                                                 ...          ...
# 266                                        Yugoslavia            YU
# 267                                                  Z          NaN
# 268  Zaire (Former Congo Free State, Belgian Congo,...           ZR
# 269    Zambia, Republic of (Former Northern Rhodesia)            ZM
# 270  Zimbabwe, Republic of (Former Southern Rhodesi...           ZW
#
#     International_dialing
# 0                     NaN
# 1                     +93
# 2                    +355
# 3                    +213
# ...

# %%
def country(df):
    for index,row in df.iterrows():
        df.at[index,'Country_Code']=row['address'][-8:-6]

# %%
#df['Country_Code']=df['Country_Code'].str.slice(-8,-6)

# %%
country(df)

# %%
df['phone']=df['phone'].str.replace('-','')

# %%
df.head(2)
# Out:
#    customer_id           name                        email       phone  \
# 0            1  Michelle Kidd           vayala@example.net  6197234258
# 1            2    Brad Newton  taylorcatherine@example.net  5376741158
#
#                                              address registration_date  \
# 0                        USNS Santiago, FPO AE 80872        25-01-2025
# 1  38783 Oliver Street, West Kristenborough, MT 9...        13-07-2023
#
#   loyalty_status Country_Code
# 0           Gold           AE
# 1         Silver           MT

# %%
# merge_df=pd.merge('df','countries',on='country_code',how='left')

# %%
df['phone']=df['phone'].astype(str)
for i in range(len(df)):
    code = df.loc[i,'Country_Code']
    found=False
    for j in range(len(countries)):
        if code == countries.loc[j,'Country_code']:
            dial = countries.loc[j,'International_dialing']
            df.loc[i,'phone']=(str(dial)+" "+df.loc[i,'phone'])
            found = True
            break
    if not found:
        df.loc[i,'phone']=('+1 '+df.loc[i,'phone'])

# %%
df.head()
# Out:
#    customer_id              name                        email  \
# 0            1     Michelle Kidd           vayala@example.net
# 1            2       Brad Newton  taylorcatherine@example.net
# 2            3      Larry Torres         dsanchez@example.net
# 3            4    Kimberly Price    jessicaknight@example.com
# 4            5  Matthew Phillips        qwilliams@example.com
#
#              phone                                            address  \
# 0  +971 6197234258                        USNS Santiago, FPO AE 80872
# 1  +356 5376741158  38783 Oliver Street, West Kristenborough, MT 9...
# 2    +1 8102564505     6845 Steele Turnpike, West Erikabury, UT 37487
# 3    +1 4232229779         1631 Alexis Meadows, Lake Amanda, CA 75179
# 4    +1 2207633522  2274 Williams Heights Suite 895, Andersonhaven...
#
#   registration_date loyalty_status Country_Code
# 0        25-01-2025           Gold           AE
# 1        13-07-2023         Silver           MT
# ...
